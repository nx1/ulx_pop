# %%
import sys

sys.path.append('../src')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import populations
from results_processor import ResultsProcessor

# %%
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# %%
PERCENT_ALIVE_EARNSHAW = 0.8271604938271605 * 100
PERCENT_ALIVE_EARNSHAW_ERROR = 0.12256472421344072 * 100

PERCENT_ALIVE_EARNSHAW_UPPER = PERCENT_ALIVE_EARNSHAW + PERCENT_ALIVE_EARNSHAW_ERROR
PERCENT_ALIVE_EARNSHAW_LOWER = PERCENT_ALIVE_EARNSHAW - PERCENT_ALIVE_EARNSHAW_ERROR

PERCENT_TRANS_EARNSHAW = 0.1728395061728395 * 100
PERCENT_TRANS_EARNSHAW_ERROR = 0.03744750536124969 * 100
PERCENT_TRANS_EARNSHAW_UPPER = PERCENT_TRANS_EARNSHAW + PERCENT_TRANS_EARNSHAW_ERROR
PERCENT_TRANS_EARNSHAW_LOWER = PERCENT_TRANS_EARNSHAW - PERCENT_TRANS_EARNSHAW_ERROR

N_alive = 67
N_alive_std = 7.452910803632364
N_trans = 14
N_trans_std = 2.706010895876068

A_T = N_alive / N_trans
A_T_std = A_T * np.sqrt((PERCENT_ALIVE_EARNSHAW_ERROR/PERCENT_ALIVE_EARNSHAW)**2 + (PERCENT_TRANS_EARNSHAW_ERROR/PERCENT_TRANS_EARNSHAW)**2 )
A_T_upper = A_T + A_T_std
A_T_lower = A_T - A_T_std

# %%
df = populations.startrack_v2_mt_1_all()
pop = populations.Population(df)
# Out:
# /home/x1/.local/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in arccos
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Create sim object    
rp = ResultsProcessor()

# Set Database
db_path = '../src/ulxlc.db'
rp.set_active_db(db_path)

# Insert population
rp.set_parent_population(pop)

# %%
rp.get_run_ids(True)
# Out:
# {(500, 0.0, 21, '0.0002'): ['52df1c22-d0a3-4b49-be37-9e513c0deb68', '0cf3a80a-015a-493d-afd1-7968dac772be', '10f67240-0bc8-4e1f-818f-21c5d85d9a36', '84d84ff0-3c9d-4b26-b2b2-f3bccbad381f', '4705a372-15ff-453f-a02b-5710ef250942', '42f7bbcf-c4d6-4b9b-b8ce-135550471fca', '90c288d5-cfbb-4bc1-9191-50dc3ba2b6e6', '1c004147-aefb-4ebc-80a7-4d6c3d628b68', '30b8c767-e92f-4476-84c5-a66e2a328954', 'b9392e23-62ef-4cc7-a444-ba1161b9cae2', '4c085d8d-8c8f-42dd-98d2-9c9a396479f7', 'd6df043e-5fbf-4774-9f84-1430adfa98d6', 'da672a9c-8b1c-4731-be9e-bd7e27175488', '1f93db24-b018-42ff-8c5b-c7a58562c10d', '4af1fe56-fb46-4ebd-a199-4ccdce72403c', 'f253d9af-26d9-4772-b1ff-dbbd53583344', '8272e710-0b9d-444a-a97b-4ebe363b9904', 'a5a96330-bec1-482e-a51f-98c4c0970fc7', '65738b6e-6467-4490-9c46-594305518207', '202d7f48-3f67-4a24-9a74-ff43cd2087e9', '90bb4965-554f-4677-b52e-152ff00cfecb', '3ad362fc-b64a-44da-984f-928289ebac96', '7894ea80-651d-42eb-b7c5-cfe
470a-b974-4ac798a77003', '17c22821-6449-41fa-b187-c09439145d53', 'c0e607eb-8130-459b-8f67-2cc4dcf9aade', 'c5fb1901-9f6b-4539-b590-4d9dc86209f1', 'c16ed8b1-0cde-470f-8f96-48d4f598ee6e', '5c2832b4-92e9-4fcb-88c8-7aef0b5a47eb', '739a95d0-40d7-4279-80db-4e4e2e9628bb', 'b8c11623-7de6-4153-b597-11fec4826f67', '3f45b1ee-dab1-42fe-a6cb-c80637250e2b', 'b1f78b27-1bbf-421a-a10e-797282ddefee', '65295f1d-8e40-4a05-88bb-3e329459277a', 'f2837be4-8e9f-4987-bc55-89327e0b6042', '71dbb769-f496-4890-83b8-8c82796d822c', '8386a7c8-8395-4cff-b05b-38231c979952', 'd00821f9-6966-49aa-884e-08572a52bd54', '9375e862-4fef-4f31-b804-c43ba696128d', 'a254edd7-df1e-48a1-a3de-5db1d390114c', '316b34b0-92be-4fb7-8789-3bfbde740599', '5585fe14-e7c6-4775-a6db-5571a65ae833', '30bfa3eb-73ca-4938-bcf6-aed3f7661360', '7bbf8fa4-604f-4e22-9b3f-8e3fdbd7841c', 'bfc6c6bf-6f ...

# %%
rp.table_load_classifications()

# %%
df2 = pd.DataFrame()
for d in [1.0, 0.3, 0.2, 0.1]:
    print(d)
    if d != 1.0:
        rp.sim_classifications_sampler_with_duty_cycle(d)
        rp.df_classifications['lc_classification'] = rp.df_classifications['lc_classification_new']


    df = rp.calc_all_classifications_count_stats()
    df['d']=d
    df2 = df2.append(df)
# Out:
# 1.0
# (500, 0.0, 21, '0.0002')
# (500, 0.0, 21, '0.002')
# (500, 0.0, 21, '0.02')
# (500, 0.0, 46, '0.0002')
# (500, 0.0, 46, '0.002')
# (500, 0.0, 46, '0.02')
# (500, 0.25, 21, '0.0002')
# (500, 0.25, 21, '0.002')
# (500, 0.25, 21, '0.02')
# (500, 0.25, 46, '0.0002')
# (500, 0.25, 46, '0.002')
# (500, 0.25, 46, '0.02')
# (500, 0.5, 21, '0.0002')
# (500, 0.5, 21, '0.002')
# (500, 0.5, 21, '0.02')
# (500, 0.5, 46, '0.0002')
# (500, 0.5, 46, '0.002')
# (500, 0.5, 46, '0.02')
# (500, 0.75, 21, '0.0002')
# (500, 0.75, 21, '0.002')
# (500, 0.75, 21, '0.02')
# (500, 0.75, 46, '0.0002')
# (500, 0.75, 46, '0.002')
# (500, 0.75, 46, '0.02')
# (500, 1.0, 21, '0.0002')
# (500, 1.0, 21, '0.002')
# (500, 1.0, 21, '0.02')
# (500, 1.0, 46, '0.0002')
# (500, 1.0, 46, '0.002')
# (500, 1.0, 46, '0.02')
# 0.3
# (500, 0.0, 21, '0.0002')
# (500, 0.0, 21, '0.002')
# (500, 0.0, 21, '0.02')
# (500, 0.0, 46, '0.0002')
# (500, 0.0, 46, '0.002')
# (500, 0.0, 46, '0.02')
# (500, 0.25, 21, '0.0002')
# (500, 0.25, 21, '0.002')
# (500, 0.25, 21, '0.02')
# (500, 0.25, 46, '0.0002')
# (500, 0.25, 46, '0.002')
# (500, 0.25, 46, '0.02')
# (500, 0.5, 21, '0.0002')
# (500, 0.5, 21, '0.002')
# (500, 0.5, 21, '0.02')
# (500, 0.5, 46, '0.0002')
# (500, 0.5, 46, '0.002')
# (500, 0.5, 46, '0.02')
# (500, 0.75, 21, '0.0002')
# (500, 0.75, 21, '0.002')
# (500, 0.75, 21, '0.02')
# (500, 0.75, 46, '0.0002')
# (500, 0.75, 46, '0.002')
# (500, 0.75, 46, '0.02')
# (500, 1.0, 21, '0.0002')
# (500, 1.0, 21, '0.002')
# (500, 1.0, 21, '0.02')
# (500, 1.0, 46, '0.0002')
# (500, 1.0, 46, '0.002')
# (500, 1.0, 46, '0.02')
# 0.2
# (500, 0.0, 21, '0.0002')
# (500, 0.0, 21, '0.002')
# (500, 0.0, 21, '0.02')
# (500, 0.0, 46, '0.0002')
# (500, 0.0, 46, '0.002')
# (500, 0.0, 46, '0.02')
# (500, 0.25, 21, '0.0002')
# (500, 0.25, 21, '0.002')
# (500, 0.25, 21, '0.02')
# (500, 0.25, 46, '0.0002')
# (500, 0.25, 46, '0.002')
# (500, 0.25, 46, '0.02')
# (500, 0.5, 21, '0.0002')
# (500, 0.5, 21, '0.002')
# (500, 0.5, 21, '0.02')
# (500, 0.5, 46, '0.0002')
# (500, 0.5, 46, '0.002')
# (500, 0.5, 46, '0.02')
# (500, 0.75, 21, '0.0002')
# (500, 0.75, 21, '0.002')
# (500, 0.75, 21, '0.02')
# (500, 0.75, 46, '0.0002')
# (500, 0.75, 46, '0.002')
# (500, 0.75, 46, '0.02')
# (500, 1.0, 21, '0.0002')
# (500, 1.0, 21, '0.002')
# (500, 1.0, 21, '0.02')
# (500, 1.0, 46, '0.0002')
# (500, 1.0, 46, '0.002')
# (500, 1.0, 46, '0.02')
# 0.1
# (500, 0.0, 21, '0.0002')
# (500, 0.0, 21, '0.002')
# (500, 0.0, 21, '0.02')
# (500, 0.0, 46, '0.0002')
# (500, 0.0, 46, '0.002')
# (500, 0.0, 46, '0.02')
# (500, 0.25, 21, '0.0002')
# (500, 0.25, 21, '0.002')
# (500, 0.25, 21, '0.02')
# (500, 0.25, 46, '0.0002')
# (500, 0.25, 46, '0.002')
# (500, 0.25, 46, '0.02')
# (500, 0.5, 21, '0.0002')
# (500, 0.5, 21, '0.002')
# (500, 0.5, 21, '0.02')
# (500, 0.5, 46, '0.0002')
# (500, 0.5, 46, '0.002')
# (500, 0.5, 46, '0.02')
# (500, 0.75, 21, '0.0002')
# (500, 0.75, 21, '0.002')
# (500, 0.75, 21, '0.02')
# (500, 0.75, 46, '0.0002')
# (500, 0.75, 46, '0.002')
# (500, 0.75, 46, '0.02')
# (500, 1.0, 21, '0.0002')
# (500, 1.0, 21, '0.002')
# (500, 1.0, 21, '0.02')
# (500, 1.0, 46, '0.0002')
# (500, 1.0, 46, '0.002')
# (500, 1.0, 46, '0.02')

# %%
rp.sim_classifications_sampler_with_duty_cycle(0.1)

# %%
print(rp.df_classifications['lc_classification'].value_counts().sort_index())
print(rp.df_classifications['lc_classification_new'].value_counts().sort_index())
# Out:
# 0    3877268
# 1    3388568
# 2    3539811
# Name: lc_classification, dtype: int64
# 0    3877268
# 1    3388568
# 2    3539811
# Name: lc_classification_new, dtype: int64

# %%
df3 = df2.copy()
Z = []
dincl_cutoff = []
bh_ratio = []
for i in df3.index:
    Z.append(i[0])
    dincl_cutoff.append(i[1])
    bh_ratio.append(i[2])
    
df3['Z']=Z
df3['dincl_cutoff']=dincl_cutoff
df3['bh_ratio']=bh_ratio

# %%
df3 = df3.set_index(['Z', 'dincl_cutoff', 'bh_ratio', 'd'])

# %%
df3.loc[:,46,:]
# Out:
#                     N_dead                                     N_trans  \
#                        min        mean    max        std count     min
# Z      bh_ratio d
# 0.0002 0.00     1.0  111.0  138.242591  166.0   9.790632   911   181.0
#        0.25     1.0   82.0  110.508233  145.0   9.539028   911   165.0
#        0.50     1.0   52.0   83.397273  108.0   8.082344  1100   145.0
#        0.75     1.0   35.0   55.680571   79.0   6.666634   911   129.0
#        1.00     1.0   13.0   27.954995   46.0   5.280605   911   112.0
# 0.002  0.00     1.0   91.0  126.057000  151.0   9.275332  1000   141.0
#        0.25     1.0   77.0  103.354000  131.0   8.986737  1000   134.0
#        0.50     1.0   54.0   80.020000  106.0   8.076385  1100   123.0
#        0.75     1.0   35.0   56.511000   81.0   6.898222  1000   108.0
#        1.00     1.0   18.0   33.237000   52.0   5.585520  1000   100.0
# 0.02   0.00     1.0  128.0  160.315556  190.0  10.386008   900   173.0
#        0.25     1.0   98.0  129.680000  159.0   9.172057   900   163.0
#        0.50     1.0   17.0   99.491014  133.0   8.600211  1558    55.0
#        0.75     1.0   50.0   69.758621   92.0   7.144907   899   122.0
#        1.00     1.0   22.0   39.236930   62.0   5.881583   899   112.0
# 0.0002 0.00     0.3  134.0  162.787047  197.0  10.352718   911   167.0
#        0.25     0.3  103.0  129.496158  164.0   9.883038   911   150.0
#        0.50     0.3   66.0   96.799091  121.0   8.375329  1100   135.0
#        0.75     0.3   43.0   63.466520   84.0   6.806003   911   126.0
#        1.00     0.3   14.0   29.854007   47.0   5.327060   911   108.0
# 0.002  0.00     0.3   94.0  131.075000  160.0   9.433577  1000   137.0
#        0.25     0.3   79.0  111.349000  141.0   9.255423  1000   126.0
#        0.50     0.3   66.0   90.946364  114.0   8.462831  1100   117.0
#        0.75     0.3   48.0   70.690000  105.0   7.706964  1000   102.0
#        1.00     0.3   29.0   50.498000   71.0   6.758674  1000    96.0
# 0.02   0.00     0.3  139.0  170.824444  202.0  10.387822   900   165.0
#        0.25     0.3  110.0  148.353333  185.0   9.906327   900   146.0
#        0.50     0.3   34.0  126.462131  162.0   9.783569  1558    42.0
#        0.75     0.3   79.0  104.988877  134.0   8.923074   899   105.0
#        1.00     0.3   59.0   82.731924  113.0   8.263236   899    82.0
# 0.0002 0.00     0.2  132.0  166.373216  199.0  10.391517   911   165.0
#        0.25     0.2  101.0  132.141603  164.0   9.887206   911   149.0
#        0.50     0.2   72.0   98.603636  123.0   8.429291  1100   133.0
#        0.75     0.2   43.0   64.557629   83.0   6.857476   911   126.0
#        1.00     0.2   14.0   30.164654   47.0   5.462087   911   110.0
#        0.50     0.2           9.032258  41.141080  50.406504  2.588894  1558
#        0.75     0.2          27.202073  33.258557  40.703518  2.256824   899
#        1.00     0.2          19.704433  26.297373  33.175355  2.183864   899
# 0.0002 0.00     0.1          49.546828  58.384443  67.901235  2.639845   911
#        0.25     0.1          42.148760  49.442070  56.353591  2.549927   911
#        0.50     0.1          33.502538  41.710383  48.780488  2.342182  1100
#        0.75     0.1          28.801843  35.411666  42.923434  2.202710   911
#        1.00     0.1          23.376623  30.067077  35.668790  2.083851   911
# 0.002  0.00     0.1          37.637363  46.378687  55.466667  2.556711  1000
#        0.25     0.1          33.421053  40.780768  47.089947  2.327345  1000
#        0.50     0.1          28.817734  35.725422  42.014742  2.277815  1100
#        0.75     0.1          23.394495  31.102276  38.479810  2.186934  1000
#        1.00     0.1          20.541761  27.000829  34.396355  2.080355  1000
# 0.02   0.00     0.1          51.497006  60.082766  68.000000  2.731498   900
#        0.25     0.1          42.732558  50.039033  56.886228  2.455660   900
#        0.50     0.1           8.061002  40.893207  49.863014  2.585315  1558
#        0.75     0.1          26.631854  32.845978  40.306122  2.228748   899
#        1.00     0.1          19.458128  25.754946  33.253589  2.225459   899
#
# [60 rows x 35 columns]

# %%
#plt.figure(figsize=(7,7))

fig, ax = plt.subplots(nrows=1,ncols=len(DCS), figsize=(20,5))
for a in ax:
    a.set_xlabel('%Transient')
    a.set_xlim(0,70)
    a.set_ylabel(r'$\%_{\mathrm{BH}}$')
    a.set_ylim(0,105)
    a.axvspan(PERCENT_TRANS_EARNSHAW_LOWER, PERCENT_TRANS_EARNSHAW_UPPER, fill='', linestyle='--')
    a.text(x=PERCENT_TRANS_EARNSHAW, y=20, s='XMM', rotation=90)
    
    
#plt.xlabel('%Transient')
#plt.xlim(0,70)

#plt.ylabel(r'$\%_{\mathrm{BH}}$')
plt.ylim(0,105)

plt.axvspan(PERCENT_TRANS_EARNSHAW_LOWER, PERCENT_TRANS_EARNSHAW_UPPER, fill='', linestyle='--')
plt.text(x=PERCENT_TRANS_EARNSHAW, y=20, s='XMM', rotation=90)

BHS = [0,0.25,0.5,0.75,1.0]
DCS = [1.0,0.3,0.2,0.1]
BHS_100 = [100*b for b in BHS]



for Z in ['0.02', '0.002', '0.0002']:
    for dincl in [21, 46]:
        for i, d in enumerate(DCS):
            M = []
            STD = []
            xlow = []
            xhigh = []
            for bh in BHS:
                sub = df3['frac_trans_visible'].loc[Z,dincl,bh,d]
                m = sub['mean']
                std = sub['std']

                xlow.append(m-std)
                xhigh.append(m+std)
                STD.append(std)

                #print(Z, dincl, bh, m, std)
                #plt.errorbar(x=m, y=100*bh, xerr=std)
            ax[i].set_title(f'd={d}')
            ax[i].fill_betweenx(y=BHS_100, x1=xlow, x2=xhigh, alpha=0.5, label=f'Z={Z} dincl={dincl}')

for a in ax:
    a.legend()
#plt.savefig('regions.png', dpi=1000)
plt.show()

# %%
#plt.figure(figsize=(7,7))

ncols = 2
w = 6.93
h = w/ncols

fig, ax = plt.subplots(nrows=1,ncols=ncols, figsize=(10,5), sharey=True)
fig.set_size_inches([w,h])

ax[0].set_ylabel(r'$\%_{\mathrm{BH}}$')
for a in ax:
    a.set_xlabel('%Transient')
    a.set_xlim(0,75)
    
    a.set_ylim(0,105)
    a.axvspan(PERCENT_TRANS_EARNSHAW_LOWER, PERCENT_TRANS_EARNSHAW_UPPER, fill='', linestyle='--')
    a.text(x=PERCENT_TRANS_EARNSHAW-1, y=5, s='XMM', rotation=90)
plt.subplots_adjust(wspace=0)
    
#plt.xlabel('%Transient')
#plt.xlim(0,70)

#plt.ylabel(r'$\%_{\mathrm{BH}}$')
plt.ylim(0,105)



BHS = [0,0.25,0.5,0.75,1.0]
DCS = [1.0, 0.1]
BHS_100 = [100*b for b in BHS]


colors = ['C0','C1','C2','C0','C1','C2']
linestyles = ['-', '-', '-', '--','--','--']

j=0
for dincl in [21, 46]:
    for Z in ['0.02', '0.002', '0.0002']:
        for i, d in enumerate(DCS):
            M = []
            STD = []
            xlow = []
            xhigh = []
            for bh in BHS:
                sub = df3['frac_trans_visible'].loc[Z,dincl,bh,d]
                m = sub['mean']
                std = sub['std']

                xlow.append(m-std)
                xhigh.append(m+std)
                STD.append(std)

                #print(Z, dincl, bh, m, std)
                #plt.errorbar(x=m, y=100*bh, xerr=std)
            ax[i].set_title(f'd={d}')
            ax[i].fill_betweenx(y=BHS_100, x1=xlow, x2=xhigh, alpha=0.8, label=fr'Z={Z} $\Delta i_{{max}}=${dincl-1}$^{{\circ}}$', facecolor='None', ec=colors[j], linestyle=linestyles[j])
        j+=1

for a in ax:
    a.legend(prop={'size': 7})
    

plt.savefig('../reports/figures/BH_ratio_constraint.pdf')
plt.savefig('../reports/figures/BH_ratio_constraint.png', dpi=1000)
plt.show()
plt.tight_layout()

# %%
rp.table_load_erass_evolution()
Z='0.02'
duty_cycle=0.1

cycles = ['1', '2', '3', '4', '5', '6', '7', '8']
dincls = rp.df_erass_mc_info['dincl_cutoff'].unique()
bh_percents = np.sort(rp.df_erass_mc_info['bh_ratio'].unique())

erass_system_period_cutoff = 999999

for i, dincl in enumerate(dincls):
    for j, bh in enumerate(bh_percents):
        key = (500, bh, dincl, Z, erass_system_period_cutoff)
        df = rp.get_erass_evolution_from_key(key)

        df = df[df['duty_cycle']==duty_cycle]

        sub_wind = df[df['period'] == 'P_wind']
        sub_sup = df[df['period'] == 'P_sup']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-226-4ad19c963e6e> in <module>
#      12     for j, bh in enumerate(bh_percents):
#      13         key = (500, bh, dincl, Z, erass_system_period_cutoff)
# ---> 14         df = rp.get_erass_evolution_from_key(key)
#      15
#      16         df = df[df['duty_cycle']==duty_cycle]
#
# /mnt/c/Users/norma/Desktop/gitbox/ulx_pop/src/results_processor.py in get_erass_evolution_from_key(self, key)
#     577             self.get_run_ids(group_period_cutoff=False)
#     578
# --> 579         ids = self.dict_MC_run_ids[key]
#     580         df_erass_evolution = self.df_erass_evolution.set_index('run_id')
#     581         df_erass_evolution = df_erass_evolution.loc[df_erass_evolution.index.intersection(ids).unique()]
#
# KeyError: (500, 0.0, 21, '0.02', 999999)

# %%
duty_cycles = [1.0,0.3,0.2,0.1]

df_res_wind = pd.DataFrame()
df_res_sup = pd.DataFrame()



for d in duty_cycles:
    print(f'duty_cycle:{d}')
    for k in rp.dict_MC_run_ids.keys():
        print(k)
        size = k[0]
        bh = k[1]
        dincl_max = k[2]
        Z = k[3]
        
        df = rp.get_erass_evolution_from_key(k)
        df = df[df['duty_cycle']==duty_cycle]

        df['percent_obs'] = (df['N_total_systems']/500) * 100
        df['percent_trans_to_obs'] = df['N_transients_cum'] / df['N_total_systems'] * 100

        sub_wind = df[df['period'] == 'P_wind']
        sub_sup = df[df['period'] == 'P_sup']

        agg_wind = sub_wind.groupby(['erass_cycle']).agg(['mean', 'std'])
        agg_sup = sub_sup.groupby(['erass_cycle']).agg(['mean', 'std'])
# Out:
# (500, 0.0, 21, '0.0002')
# (500, 0.0, 21, '0.002')
# (500, 0.0, 21, '0.02')
# (500, 0.0, 46, '0.0002')
# (500, 0.0, 46, '0.002')
# (500, 0.0, 46, '0.02')
# (500, 0.25, 21, '0.0002')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-269-bbe19349cd14> in <module>
#      14         Z = k[3]
#      15
# ---> 16         df = rp.get_erass_evolution_from_key(k)
#      17         df = df[df['duty_cycle']==duty_cycle]
#      18
#
# /mnt/c/Users/norma/Desktop/gitbox/ulx_pop/src/results_processor.py in get_erass_evolution_from_key(self, key)
#     579         ids = self.dict_MC_run_ids[key]
#     580         df_erass_evolution = self.df_erass_evolution.set_index('run_id')
# --> 581         df_erass_evolution = df_erass_evolution.loc[df_erass_evolution.index.intersection(ids).unique()]
#     582         return df_erass_evolution
#     583
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in intersection(self, other, sort)
#    2661         rvals = other._values
#    2662
# -> 2663         if self.is_monotonic and other.is_monotonic:
#    2664             try:
#    2665                 result = self._inner_indexer(lvals, rvals)[0]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in is_monotonic(self)
#    1568         Alias for is_monotonic_increasing.
#    1569         """
# -> 1570         return self.is_monotonic_increasing
#    1571
#    1572     @property
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in is_monotonic_increasing(self)
#    1585         False
#    1586         """
# -> 1587         return self._engine.is_monotonic_increasing
#    1588
#    1589     @property
#
# KeyboardInterrupt:

# %%
agg_sup['N_transients']
# Out:
#                   mean       std
# erass_cycle
# 1             0.000000  0.000000
# 2            86.388889  8.626723
# 3            22.653333  4.766849
# 4            10.120000  3.131710
# 5             5.955556  2.484260
# 6             3.600000  1.901349
# 7             2.661111  1.586104
# 8             1.904444  1.395919

# %%
# Out:
#                   mean       std
# erass_cycle
# 1             0.000000  0.000000
# 2            11.336945  2.129160
# 3            15.752779  2.372344
# 4            18.362550  2.511681
# 5            20.253120  2.576310
# 6            21.697373  2.636430
# 7            22.788774  2.681095
# 8            23.665343  2.689641

# %%
Things to measure:
    % Transient / observed
    % Transient / observed_std
    
    % underlying population observed
    % underlying population observed_std

# %%
N_transient_wind
# Out:
#                   mean       std
# erass_cycle
# 1             0.000000  0.000000
# 2            25.856667  4.962654
# 3            10.967778  3.330525
# 4             6.744444  2.635267
# 5             5.035556  2.270099
# 6             3.908889  2.010686
# 7             3.016667  1.737101
# 8             2.423333  1.550668

# %% [raw]
# As established in section \ref{sec:comp_to_obs}, the relative percentage of transient to observed
# systems may serve as a gauge of the underlying population demographic. In this section, we perform
# simulations to see to what degree and accuracy \erosita \ and its acccompanying all sky survey \erass
# will be able to constrain this figure.
#
# In order to account for \erass regular cadence of six months, we must introduce a physical dimensions
# to the temporal part of our lightcurves. to do this... (phil charles etc)
#
# We then sampled our curves ... (etc)
#
# and at each erass cycle calculated the cumulative percentage of transient to observed systems, as well as what percentage of the underlying sample of 500 had been observed,
#
#     %_Transient/observed =
#     %_underlying_population_sampled =
#
# and their accompanying 1 sigma standard deviations.

# %%
What percentage of the transient population was identified by erass?

# %%
1. get run id.
2. get # of transients
3. get # of transients in cycle 8

compare.

# %%
rp.table_load_classifications()
rp.table_load_erass_evolution()

# %%
gb = rp.df_classifications.groupby(['run_id'])['lc_classification']

# %%
def lc_class_counts(df):
    vc = df.value_counts()
    vc['4']=500-vc.sum()
    return vc

# %%
res = gb.apply(lc_class_counts)

# %%
res

# %%
cycle_8 = rp.df_erass_evolution[rp.df_erass_evolution['erass_cycle']==8]
cycle_8 = cycle_8[cycle_8['duty_cycle']==1.0]

# %%
cycle_8
# Out:
#          erass_cycle  N_new_systems  N_old_system_become_transient  \
# 7                  8              1                              0
# 15                 8              0                              0
# 71                 8              1                              0
# 79                 8              1                              1
# 135                8              0                              1
# ...              ...            ...                            ...
# 1920463            8              2                              0
# 1920519            8              1                              0
# 1920527            8              0                              2
# 1920583            8              0                              0
# 1920591            8              2                              0
#
#          N_observed_ulxs  N_delta_obs_ulx  N_transients  N_transients_cum  \
# 7                    410                1             1                 8
# 15                   422                0             0                47
# 71                   384                1             1                 9
# 79                   390                0             2                48
# 135                  386               -1             1                29
# ...                  ...              ...           ...               ...
# 1920463              269                2             2                58
# 1920519              350                1             1                34
# 1920527              354               -2             2               111
# 1920583              220                0             0                25
# 1920591              280                2             2               140
#
#          N_total_systems  N_persistent_ulx_systems  period  duty_cycle  \
# 7                    415                       407  P_wind         1.0
# 15                   438                       391   P_sup         1.0
# 71                   388                       379  P_wind         1.0
# 79                   411                       363   P_sup         1.0
# 135                  399                       370  P_wind         1.0
# ...                  ...                       ...     ...         ...
# 1920463              299                       241   P_sup         1.0
# 1920519              371                       337  P_wind         1.0
# 1920527              415                       304   P_sup         1.0
# 1920583              232                       207  P_wind         1.0
# 1920591              321                       181   P_sup         1.0
#
#                                        run_id
# 7        00002ed0-1c02-4b71-8fb9-5d94a962ecec
# 15       00002ed0-1c02-4b71-8fb9-5d94a962ecec
# 71       0001b901-4bab-4c74-a9a3-395d1792c4bf
# 79       0001b901-4bab-4c74-a9a3-395d1792c4bf
# 135      0002b574-5dc8-44ba-8ba7-8ee2257ff6cf
# ...                                       ...
# 1920463  fffccd2d-ed7a-43cd-843b-1909a2869fac
# 1920519  fffd1d48-8875-4011-b00a-32093b228e7c
# 1920527  fffd1d48-8875-4011-b00a-32093b228e7c
# 1920583  fffe42f8-d895-44c5-b29e-79f8a889b31f
# 1920591  fffe42f8-d895-44c5-b29e-79f8a889b31f
#
# [60020 rows x 12 columns]
